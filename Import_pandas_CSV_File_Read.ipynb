# %% [markdown]
# <a href="https://colab.research.google.com/github/jobayed80/C-Project/blob/main/Import_pandas_CSV_File_Read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('shanghaiData.csv')
#if the file slxs, then
# df = pd.read_excel('file-name.xlsx')

# %%
df
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 2             3                          Stanford University             2
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# ...         ...                                          ...           ...
# 4892    401-500                        University of Trieste         11-20
# 4893    401-500                       University of Zaragoza          9-13
# 4894    401-500                        Utah State University       126-146
# 4895    401-500              Vienna University of Technology           4-6
# 4896    401-500                       Wake Forest University       126-146
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# ...

# %%
df.shape
# Out:
# (4897, 11)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# head() function that means first 5(default) rows show.
df.head()
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
# tail() this function used for last five(default) rows show
df.tail()
# Out:
#      world_rank                  university_name national_rank  total_score  \
# 4892    401-500            University of Trieste         11-20          NaN
# 4893    401-500           University of Zaragoza          9-13          NaN
# 4894    401-500            Utah State University       126-146          NaN
# 4895    401-500  Vienna University of Technology           4-6          NaN
# 4896    401-500           Wake Forest University       126-146          NaN
#
#       alumni  award  hici    ns   pub   pcp  year
# 4892     0.0    0.0   5.0  10.9  25.1  20.1  2015
# 4893     0.0    0.0   7.6   5.1  33.3  13.1  2015
# 4894    13.6    0.0   3.6  10.8  25.1  15.5  2015
# 4895     0.0    0.0   0.0  12.2  28.8  22.9  2015
# 4896     0.0    0.0  14.9   7.5  25.0  11.9  2015

# %%
# head(10) that means first ten rows show
df.head(10)
# Out:
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
# 5          6           California Institute of Technology             5
# 6          7                          Columbia University             6
# 7          8                         Princeton University             7
# 8          9                        University of Chicago             8
# 9         10                         University of Oxford             2
#
#    total_score  alumni  award   hici     ns    pub    pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0   72.4  2005
# ...

# %%
# tail(10) that means last ten rows show
df.tail(10)
# Out:
#      world_rank                   university_name national_rank  total_score  \
# 4887    401-500   University of Science, Malaysia             2          NaN
# 4888    401-500             University of Seville          9-13          NaN
# 4889    401-500              University of Surrey         34-37          NaN
# 4890    401-500              University of Szeged           1-2          NaN
# 4891    401-500  University of the Basque Country          9-13          NaN
# 4892    401-500             University of Trieste         11-20          NaN
# 4893    401-500            University of Zaragoza          9-13          NaN
# 4894    401-500             Utah State University       126-146          NaN
# 4895    401-500   Vienna University of Technology           4-6          NaN
# 4896    401-500            Wake Forest University       126-146          NaN
#
#       alumni  award  hici    ns   pub   pcp  year
# 4887     0.0    0.0   7.1   3.3  30.6  15.7  2015
# ...

# %%
# Shows total values in DataFrame
df.values
# Out:
# array([['1', 'Harvard University', '1', ..., 100.0, 72.4, 2005],
#        ['2', 'University of Cambridge', '1', ..., 70.9, 66.9, 2005],
#        ['3', 'Stanford University', '2', ..., 72.3, 65.0, 2005],
#        ...,
#        ['401-500', 'Utah State University', '126-146', ..., 25.1, 15.5,
#         2015],
#        ['401-500', 'Vienna University of Technology', '4-6', ..., 28.8,
#         22.9, 2015],
#        ['401-500', 'Wake Forest University', '126-146', ..., 25.0, 11.9,
#         2015]], dtype=object)

# %%
#names of columns
df.columns
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'hici', 'ns', 'pub', 'pcp', 'year'],
#       dtype='object')

# %%
#specific column data show and first ten data show
df.alumni.head(10)
# or = df['alumni].head(10)
# Out:
# 0    100.0
# 1     99.8
# 2     41.1
# 3     71.8
# 4     74.0
# 5     59.2
# 6     79.4
# 7     63.4
# 8     75.6
# 9     64.3
# Name: alumni, dtype: float64

# %%
#specific multiple data show and fisrt 15 data rows show
df[['alumni','university_name', 'national_rank']].head(15)
# Out:
#     alumni                              university_name national_rank
# 0    100.0                           Harvard University             1
# 1     99.8                      University of Cambridge             1
# 2     41.1                          Stanford University             2
# 3     71.8           University of California, Berkeley             3
# 4     74.0  Massachusetts Institute of Technology (MIT)             4
# 5     59.2           California Institute of Technology             5
# 6     79.4                          Columbia University             6
# 7     63.4                         Princeton University             7
# 8     75.6                        University of Chicago             8
# 9     64.3                         University of Oxford             2
# 10    52.1                              Yale University             9
# 11    46.5                           Cornell University            10
# ...

# %%
df['university_name'].sort_values().head(20)
# Out:
# 4297    Aalborg University
# 4697    Aalborg University
# 400       Aalto University
# 4797      Aalto University
# 1402      Aalto University
# 1911      Aalto University
# 900       Aalto University
# 4298      Aalto University
# 2914      Aalto University
# 3599     Aarhus University
# 3878     Aarhus University
# 3970     Aarhus University
# 2109     Aarhus University
# 3099     Aarhus University
# 1603     Aarhus University
# 100      Aarhus University
# 601      Aarhus University
# 2611     Aarhus University
# 4469     Aarhus University
# 1101     Aarhus University
# Name: university_name, dtype: object

# %%
#when used ascending = True then small to highest
#when ascending = False then highest to lowest
df.sort_values('total_score', ascending=False).head(30)
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 2514          1                           Harvard University             1
# 3897          1                           Harvard University             1
# 1510          1                           Harvard University             1
# 3798          1                           Harvard University           1.0
# 3514          1                           Harvard University             1
# 2013          1                           Harvard University             1
# 1000          1                           Harvard University             1
# 500           1                           Harvard University             1
# 3014          1                           Harvard University             1
# 4397          1                           Harvard University             1
# ...

# %%
# It is used for all numerical values but if here have String letter then ignore string letter
df.describe()
# Out:
#        total_score       alumni       award         hici           ns  \
# count  1101.000000  4896.000000  4895.00000  4895.000000  4875.000000
# mean     36.383470     9.161724     7.69191    16.221491    16.078503
# std      13.557186    14.140636    15.49411    14.382710    12.511529
# min      23.500000     0.000000     0.00000     0.000000     0.000000
# 25%      27.400000     0.000000     0.00000     7.300000     8.000000
# 50%      31.300000     0.000000     0.00000    12.600000    12.800000
# 75%      41.800000    15.600000    13.40000    21.700000    19.800000
# max     100.000000   100.000000   100.00000   100.000000   100.000000
#
#                pub          pcp         year
# count  4895.000000  4895.000000  4897.000000
# mean     38.254648    21.242329  2009.658566
# std      13.050809     9.254351     3.197576
# min       7.300000     8.300000  2005.000000
# 25%      28.900000    15.600000  2007.000000
# 50%      36.000000    19.000000  2009.000000
# ...

# %%
# If i want to do correlation with o column and other column like(X-axis and Y-axis), then
df.corr()
# Out:
# <ipython-input-39-2e7b24186b13>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              total_score    alumni     award      hici        ns       pub  \
# total_score     1.000000  0.769191  0.831950  0.870980  0.929130  0.627578
# alumni          0.769191  1.000000  0.763562  0.620527  0.694470  0.516182
# award           0.831950  0.763562  1.000000  0.669609  0.735800  0.468816
# hici            0.870980  0.620527  0.669609  1.000000  0.868726  0.674076
# ns              0.929130  0.694470  0.735800  0.868726  1.000000  0.699849
# pub             0.627578  0.516182  0.468816  0.674076  0.699849  1.000000
# pcp             0.755265  0.672102  0.729365  0.690232  0.758854  0.534018
# year           -0.009685  0.008245  0.059676  0.052731  0.053075  0.101090
#
#                   pcp      year
# ...

# %%
#conditional statement
# data type must be numerical value but not acceptable string letter/character
df['alumni'] > 50
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# Name: alumni, Length: 4897, dtype: bool

# %%
df[df['alumni'] > 50].head(100)
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# 5             6           California Institute of Technology             5
# ...         ...                                          ...           ...
# 3904          8                          Columbia University             7
# 3905          9                        University of Chicago             8
# 3906          9                         University of Oxford             2
# 3963         67             Ecole Normale Superieure - Paris             3
# 4397          1                           Harvard University             1
#
#       total_score  alumni  award   hici     ns    pub    pcp  year
# ...

# %%
#used for String value
df[df['university_name'] == 'University of Oxford']
# Out:
#      world_rank       university_name national_rank  total_score  alumni  \
# 9            10  University of Oxford             2         59.7    64.3
# 509          10  University of Oxford             2         57.6    62.0
# 1009         10  University of Oxford             2         56.4    60.3
# 1519         10  University of Oxford             2         56.8    59.0
# 2022         10  University of Oxford             2         56.3    57.6
# 2523         10  University of Oxford             2         56.4    56.2
# 3023         10  University of Oxford             2         56.4    55.5
# 3523         10  University of Oxford             2         56.1    51.2
# 3807         10  University of Oxford           2.0         55.9    51.8
# 3906          9  University of Oxford             2         57.4    51.0
# 4406         10  University of Oxford             2         56.6    49.7
#
#       award  hici    ns   pub   pcp  year
# 9      59.1  48.4  55.6  68.4  53.2  2005
# ...

# %%
df[df['university_name'] != 'University of Oxford']
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 2             3                          Stanford University             2
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# ...         ...                                          ...           ...
# 4892    401-500                        University of Trieste         11-20
# 4893    401-500                       University of Zaragoza          9-13
# 4894    401-500                        Utah State University       126-146
# 4895    401-500              Vienna University of Technology           4-6
# 4896    401-500                       Wake Forest University       126-146
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# ...

# %%
df[(df['university_name'] == 'University of Oxford') | (df['university_name'] == 'Wake Forest University')]
# Out:
#      world_rank         university_name national_rank  total_score  alumni  \
# 9            10    University of Oxford             2         59.7    64.3
# 294     203-300  Wake Forest University        91-119          NaN     0.0
# 509          10    University of Oxford             2         57.6    62.0
# 794     201-300  Wake Forest University        88-118          NaN     0.0
# 1009         10    University of Oxford             2         56.4    60.3
# 1297    203-304  Wake Forest University        89-117          NaN     0.0
# 1519         10    University of Oxford             2         56.8    59.0
# 1805    201-302  Wake Forest University        91-114          NaN     0.0
# 2022         10    University of Oxford             2         56.3    57.6
# 2412    303-401  Wake Forest University       113-138          NaN     0.0
# 2523         10    University of Oxford             2         56.4    56.2
# ...

# %%
df['university_name'].isin(['University of Oxford', 'Stanford University'])
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 4892    False
# 4893    False
# 4894    False
# 4895    False
# 4896    False
# Name: university_name, Length: 4897, dtype: bool

# %%
df[df['university_name'].isin(['University of Oxford', 'Stanford University'])]
# Out:
#      world_rank       university_name national_rank  total_score  alumni  \
# 2             3   Stanford University             2         73.4    41.1
# 9            10  University of Oxford             2         59.7    64.3
# 502           3   Stanford University             2         72.5    39.7
# 509          10  University of Oxford             2         57.6    62.0
# 1001          2   Stanford University             2         73.7    42.0
# 1009         10  University of Oxford             2         56.4    60.3
# 1511          2   Stanford University             2         73.7    40.0
# 1519         10  University of Oxford             2         56.8    59.0
# 2014          2   Stanford University             2         73.1    39.0
# 2022         10  University of Oxford             2         56.3    57.6
# 2516          3   Stanford University             3         72.1    40.2
# 2523         10  University of Oxford             2         56.4    56.2
# ...
